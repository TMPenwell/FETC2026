# %% [markdown]
# <a href="https://colab.research.google.com/github/TMPenwell/FETC2026/blob/main/FETC2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello **FETC 2026**

# %%
print ("Hello FETC")
# Out:
# Hello FETC

# %%
print("Welcome to Orlando!")
# Out:
# Welcome to Orlando!

# %%
print ("Colab is awesome")
# Out:
# Colab is awesome
